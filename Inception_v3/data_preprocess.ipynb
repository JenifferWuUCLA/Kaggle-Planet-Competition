# %%
import cv2
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img_path = '../planet/train-jpg/train_2003.jpg'
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img) / 255
plt.imshow(x)

# %%
rows = x.shape[0]
cols = x.shape[1]
plt.imshow(res)
for i in range(3):
    x[:,:,i] = np.transpose(x[:,:,i])
plt.imshow(x)

# %%
M = cv2.getRotationMatrix2D((rows/2,cols/2), 180, 1)
res = cv2.warpAffine(x,M,(rows,cols))
plt.imshow(res)
res = np.flipud()

# %%
import numpy as np
for i in xrange(10):
    print np.random.rand(1)
# Out:
# [ 0.74408987]
# [ 0.76662051]
# [ 0.28639512]
# [ 0.02557593]
# [ 0.13749529]
# [ 0.58376348]
# [ 0.0618589]
# [ 0.7978279]
# [ 0.54396408]
# [ 0.32937797]

# %%
import numpy as np
a = np.array([[1,2,3],[1,2,3]])
(a > 1).astype(np.int)
# Out:
# array([[0, 1, 1],
#        [0, 1, 1]])
